# %% [markdown]
# <h1 style="color:teal;">TP1 sur les couleurs d'une image</h1><br/>

# %% [markdown]
# <h4>On va travailler avec l'image suivante <img src="image1.png" alt ="image" width=200 height=100></h4>

# %% [markdown]
# Le code suivant permet de modifier l'image "coucher de soleil" ci dessus en ne gardant que la composante rouge des couleurs.<br/><br/>
# <b>Exécuter</b> ce code à l'aide de l'onglet Exécuter ci dessus.<br/><br/>
# <b>Modifier</b> ensuite ce code pour qu'il affiche la même image en ne conservant que la composante verte de l'image.<br/>
# **Excécuter** votre code.<br/><br/>
# **Faire de même** avec la composante bleue.

# %%
from PIL import Image

img=Image.open("image1.png")
largeur, hauteur = img.size
img2=Image.new('RGB',(largeur, hauteur))

for i in range(largeur):
    for j in range(hauteur):
        r, v, b= img.getpixel((i, j))
        img2.putpixel((i, j), (r, 0, 0))
        
img2.show()

# %%
##

# %%
import numpy as np
import matplotlib.image as mi
import matplotlib.pyplot as mp

img=mi.imread(("image1.png"))
img2=np.copy(img)
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        r, v, b = img2[i, j]
        img2[i, j]=(r, 0, 0)
        
mp.imshow(img2)
mp.show()
